# %%
import pandas as pd
import numpy as p
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')
from scipy import stats
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data_path = "/content/gdrive/MyDrive/Amazon Sales data.csv"
sales_data = pd.read_csv(data_path)
sales_data.head(5)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
#checking duplicate data like labels or features or client id/number
print(sales_data['Order ID'].is_unique)
print(sales_data.columns.is_unique)
# Out:
# True
# True

# %%
#checking any missing data and dropping non-significant features
sales_data.drop('Order ID' , axis =1 , inplace = True)
pd.isna(sales_data).any()
# Out:
# Region            False
# Country           False
# Item Type         False
# Sales Channel     False
# Order Priority    False
# Order Date        False
# Ship Date         False
# Units Sold        False
# Unit Price        False
# Unit Cost         False
# Total Revenue     False
# Total Cost        False
# Total Profit      False
# dtype: bool

# %%
#HERE NO NEED OF FURTHER DATA CLEANING REQUIRED SO WE DOWNLAOD AS .xlsx file TO
#FURTHER ANALYSIS AND KPI METRICS IN TABLEAU

excel_file_path = "sales_cleaned_data.xlsx"
sales_data.to_excel(excel_file_path , index = False)

from google.colab import files
files.download(excel_file_path)
